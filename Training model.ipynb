# %% [markdown]
# #connect to drive

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive

# %% [markdown]
# # Install and setup enviroment yolov5

# %% [markdown]
# download or git clone yolov5 repo || Done

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo

# %% [markdown]
# install enviroment and all components

# %%
# %cd /content/drive/MyDrive/yolov5
# %pip install -qr requirements.txt  # install

# %%
# %cd yolov5
# %pip install -qr requirements.txt

# %% [markdown]
# install roboflow

# %%
# %pip install -q roboflow

# %% [markdown]
# import some lib

# %%
import torch
import os
from IPython.display import Image, clear_output

# %% [markdown]
# #training model

# %%
# set up environment
os.environ["DATASET_DIRECTORY"] = "/content/drive/MyDrive/yolov5/data"

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="n5aSx2KqAsbnYLaj6GsP")
project = rf.workspace("khaigauworkspace").project("watermeter-number-detection")
dataset = project.version(3).download("yolov5")

# %%
# !python3 train.py --img 640 --batch 16 --epochs 50 --data {dataset.location}/data.yaml --weights yolov5s.pt

# %%
# !python detect.py --weights /content/drive/MyDrive/yolov5/runs/train/exp2/weights/best.pt --source /content/drive/MyDrive/yolov5/data/watermeter-number-detection-3/test/images/
